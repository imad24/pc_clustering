# %% [markdown]
# # Cluster Profiles and centroids

# %%
ca.cluster_plot(zclean_df.join(cluster_df, how="inner"))

# %%
ca.centroid_grid_plot(raw_df,clean_df,cluster_df)

# %%
# Out:
# (210, 26)
#              PC1  PC2  PC3  PC4          PR1          PR2          PR3  \
# Product
# 31C002201_2    7    5    9    4  335011700_2  335025200_2  331032200_2
# 31C002500_2    7    6    9    5  335011700_2  331700300_2  331032200_2
# 31C999901_2    7    6    2    8  335011700_2  331700300_2  331051800_2
# 31C999903_2    6    7    9   10  331700300_2  335011700_2  331032200_2
# 31C999904_2   10    4    8    1  338009400_2  336012400_2  337015200_2
#
#                      PR4  Cluster     Centroid  ...         7       8       9  \
# Product                                         ...
# 31C002201_2  336012400_2        4  336012400_2  ...     214.0   158.0   124.0
# 31C002500_2  335025200_2        9  331032200_2  ...     103.0    23.0    43.0
# 31C999901_2  337015200_2        6  331700300_2  ...      38.0    20.0    23.0
# 31C999903_2  338009400_2        6  331700300_2  ...      13.0     7.0    10.0
# 31C999904_2  331050900_2       10  338009400_2  ...    3181.0  5041.0  6729.0
#
#                  10      11      12      13      14      15     16
# Product
# 31C002201_2   127.0    84.0    35.0    23.0    29.0    11.0    6.0
# 31C002500_2     7.0     8.0    37.0     4.0    12.0     5.0    5.0
# 31C999901_2     7.0     8.0    51.0    26.0    57.0    38.0   84.0
# 31C999903_2     2.0     3.0    12.0     8.0    20.0    11.0   62.0
# 31C999904_2  8027.0  3381.0  4582.0  2675.0  2281.0  1501.0  943.0
#
# [5 rows x 26 columns]

# %% [markdown]
# # Classification: Cluster prediction
# Given a new product, we try to predict the cluster in which it lays the best

# %% [markdown]
# # Predict Quantities

# %%
# Out:
# (8, 7)
#              Mean         Std        Range        RMSE         MAE  \
# count  210.000000  210.000000   210.000000  210.000000  210.000000
# mean   343.826997  305.594226  1126.145775  267.354828  202.927839
# std    792.285712  609.203954  2227.262695  719.819579  529.862976
# min      0.729495    0.870841     3.000000    0.757752    0.558915
# 25%     23.792349   44.500844   178.372422    4.968293    3.672515
#
#              MAPE        MASE
# count  210.000000  210.000000
# mean     1.084276    1.612711
# std      0.907024    1.386577
# min      0.009635    0.029531
# 25%      0.537618    0.833771

# %% [markdown]
# ### Displaying plots
